# %%
## Task 1: Building and submitting the first Spark application (words count):

# %%
from pyspark import SparkContext, SparkConf

# %%
conf = SparkConf().setAppName("Spark Lab words count Example")

# %%
sc = SparkContext(conf=conf)

# %%
#tokenized = sc.textFile("/home/bitnami/test/AliceInWonderLandPart1.txt").flatMap(lambda line: line.split(" "))
tokenized = sc.textFile("/home/bitnami/Labs/Lab2/Data/AliceInWonderLandPart1.txt").flatMap(lambda line: line.split(" "))

# %%
wordCounts = tokenized.map(lambda word: (word, 1)).reduceByKey(lambda v1,v2:v1 +v2)

# %%
list = wordCounts.collect()
print ('[%s]' % ', '.join(map(str, list)))
# Out:
# [('', 2), ('out', 3), ('on,', 1), ('was', 5), ('suddenly', 1), ('before', 1), ('looked', 1), ('hedge.', 1), ('close', 1), ('but', 1), ('getting', 1), ('But', 1), ('trouble', 1), ('(as', 1), ('sitting', 1), ('of', 8), ('say', 1), ('own', 1), ('large', 1), ('took', 1), ('Alice,', 1), ('feel', 1), ('as', 1), ('nor', 1), ('take', 1), ('curiosity,', 1), ('hear', 1), ('book', 1), ('would', 1), ('seen', 1), ('way', 1), ('field', 1), ('reading,', 1), ('watch', 2), ('daisies,', 1), ('Once', 1), ('pictures', 2), ('it,', 2), ('burning', 1), ('when', 2), ('White', 1), ('worth', 1), ('never', 1), ('eyes', 1), ('ran', 2), ('thought', 1), ('pop', 1), ('use', 1), ('in', 4), ('very', 4), ('that,', 1), ('sister', 2), ('"without', 1), ('feet,', 1), ('after', 2), ('mind', 2), ('late!"', 1), ('stupid),', 1), ('at', 1), ('think', 1), ('Oh', 1), ('"and', 1), ('flashed', 1), ('rabbit', 1), ('is', 1), ('started', 1), ('waistcoat-pocket,', 1), ('making', 1), ('her', 6), ('down', 2), ('bank,', 1), ('no', 1), ('just', 1), ('into', 1), ('its', 1), ('dear!', 2), ('twice', 1), ('went', 1), ('by', 2), ('"Oh', 1), ('for', 2), ('nothing', 2), ('I', 1), ('with', 3), ('made', 1), ('conversations?"', 1), ('the', 12), ('and,', 1), ('moment,', 1), ('beginning', 1), ('it', 6), ('much', 1), ('daisy-chain', 1), ('rabbit-hole,', 1), ('itself,', 1), ('actually', 1), ('sleepy', 1), ('picking', 1), ('having', 1), ('day', 1), ('whether', 1), ('under', 1), ('her.', 1), ('what', 1), ('peeped', 1), ('on', 1), ('tired', 1), ('then', 1), ('and', 6), ('or', 4), ('pink', 1), ('time', 1), ('get', 1), ('either', 1), ('waistcoat-pocket', 1), ('a', 8), ('had', 3), ('across', 2), ('Alice', 4), ('remarkable', 1), ('did', 1), ('see', 1), ('another', 1), ('do.', 1), ('So', 1), ('that', 1), ('pleasure', 1), ('to', 7), ('In', 1), ('could,', 1), ('too', 1), ('hurried', 1), ('considering', 1), ('conversations', 1), ('up', 1), ('so', 2), ('well', 1), ('it!', 1), ('be', 2), ('There', 1), ('Rabbit', 3), ('book,"', 1), ('she', 5), ('shall', 1)]

# %%
wordCounts.take(10)
# Out:
# [('', 2),
#  ('out', 3),
#  ('on,', 1),
#  ('was', 5),
#  ('suddenly', 1),
#  ('before', 1),
#  ('looked', 1),
#  ('hedge.', 1),
#  ('close', 1),
#  ('but', 1)]

# %%
from IPython.display import Image
Image(filename="/home/bitnami/Labs/Lab2/ScreenShoot/Task1-2.PNG")

# %%
# !spark-submit WordCount.py
# Out:
# 22/04/03 00:40:09 WARN Utils: Your hostname, debian resolves to a loopback address: 127.0.0.1; using 10.0.2.15 instead (on interface enp0s3)
# 22/04/03 00:40:09 WARN Utils: Set SPARK_LOCAL_IP if you need to bind to another address
# 22/04/03 00:40:22 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# Using Spark's default log4j profile: org/apache/spark/log4j-defaults.properties
# 22/04/03 00:40:38 INFO SparkContext: Running Spark version 2.4.3
# 22/04/03 00:40:39 INFO SparkContext: Submitted application: Spark Lab words count Example
# 22/04/03 00:40:40 INFO SecurityManager: Changing view acls to: nu
# 22/04/03 00:40:40 INFO SecurityManager: Changing modify acls to: nu
# 22/04/03 00:40:40 INFO SecurityManager: Changing view acls groups to:
# 22/04/03 00:40:40 INFO SecurityManager: Changing modify acls groups to:
# 22/04/03 00:40:40 INFO SecurityManager: SecurityManager: authentication disabled; ui acls disabled; users  with view permissions: Set(nu); groups with view permissions: Set(); users  with modify permissions: Set(nu); groups with modify permissions: Set()
# 22/04/03 00:40:48 INFO Utils: Successfully started service 'sparkDriver' on port 35185.
# 22/04/03 00:40:49 INFO SparkEnv: Registering MapOutputTracker
# 22/04/03 00:40:50 INFO SparkEnv: Registering BlockManagerMaster
# 22/04/03 00:40:50 INFO BlockManagerMasterEndpoint: Using org.apache.spark.storage.DefaultTopologyMapper for getting topology information
# 22/04/03 00:40:50 INFO BlockManagerMasterEndpoint: BlockManagerMasterEndpoint up
# 22/04/03 00:40:50 INFO DiskBlockManager: Created local directory at /tmp/blockmgr-e0019093-f2d7-475f-80ab-70689ee1531b
# 22/04/03 00:40:51 INFO MemoryStore: MemoryStore started with capacity 366.3 MB
# 22/04/03 00:40:51 INFO SparkEnv: Registering OutputCommitCoordinator
# 22/04/03 00:40:55 WARN Utils: Service 'SparkUI' could not bind on port 4040. Attempting port 4041.
# 22/04/03 00:40:55 WARN Utils: Service 'SparkUI' could not bind on port 4041. Attempting port 4042.
# 22/04/03 00:40:55 WARN Utils: Service 'SparkUI' could not bind on port 4042. Attempting port 4043.
# 22/04/03 00:40:55 INFO Utils: Successfully started service 'SparkUI' on port 4043.
# 22/04/03 00:40:56 INFO SparkUI: Bound SparkUI to 0.0.0.0, and started at http://10.0.2.15:4043
# 22/04/03 00:40:58 INFO Executor: Starting executor ID driver on host localhost
# 22/04/03 00:41:01 INFO Utils: Successfully started service 'org.apache.spark.network.netty.NettyBlockTransferService' on port 46331.
# 22/04/03 00:41:01 INFO NettyBlockTransferService: Server created on 10.0.2.15:46331
# 22/04/03 00:41:01 INFO BlockManager: Using org.apache.spark.storage.RandomBlockReplicationPolicy for block replication policy
# 22/04/03 00:41:04 INFO BlockManagerMaster: Registering BlockManager BlockManagerId(driver, 10.0.2.15, 46331, None)
# 22/04/03 00:41:04 INFO BlockManagerMasterEndpoint: Registering block manager 10.0.2.15:46331 with 366.3 MB RAM, BlockManagerId(driver, 10.0.2.15, 46331, None)
# 22/04/03 00:41:04 INFO BlockManagerMaster: Registered BlockManager BlockManagerId(driver, 10.0.2.15, 46331, None)
# 22/04/03 00:41:04 INFO BlockManager: Initialized BlockManager: BlockManagerId(driver, 10.0.2.15, 46331, None)

# %%
## Task 2: Modify the previous example to filter out words that occur less than N times and submit the task into the Spark.:

# %%
# !spark-submit FliterLessFrequentWords.py 5
# Out:
# 22/04/03 00:04:11 WARN Utils: Your hostname, debian resolves to a loopback address: 127.0.0.1; using 10.0.2.15 instead (on interface enp0s3)
# 22/04/03 00:04:11 WARN Utils: Set SPARK_LOCAL_IP if you need to bind to another address
# 22/04/03 00:04:25 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# Using Spark's default log4j profile: org/apache/spark/log4j-defaults.properties
# 22/04/03 00:04:32 INFO SparkContext: Running Spark version 2.4.3
# 22/04/03 00:04:33 INFO SparkContext: Submitted application: SparkFilterWordCount
# 22/04/03 00:04:37 INFO SecurityManager: Changing view acls to: nu
# 22/04/03 00:04:37 INFO SecurityManager: Changing modify acls to: nu
# 22/04/03 00:04:37 INFO SecurityManager: Changing view acls groups to:
# 22/04/03 00:04:37 INFO SecurityManager: Changing modify acls groups to:
# 22/04/03 00:04:37 INFO SecurityManager: SecurityManager: authentication disabled; ui acls disabled; users  with view permissions: Set(nu); groups with view permissions: Set(); users  with modify permissions: Set(nu); groups with modify permissions: Set()
# 22/04/03 00:04:50 INFO Utils: Successfully started service 'sparkDriver' on port 36651.
# 22/04/03 00:04:52 INFO SparkEnv: Registering MapOutputTracker
# 22/04/03 00:04:55 INFO SparkEnv: Registering BlockManagerMaster
# 22/04/03 00:04:55 INFO BlockManagerMasterEndpoint: Using org.apache.spark.storage.DefaultTopologyMapper for getting topology information
# 22/04/03 00:04:55 INFO BlockManagerMasterEndpoint: BlockManagerMasterEndpoint up
# 22/04/03 00:04:55 INFO DiskBlockManager: Created local directory at /tmp/blockmgr-72bf8c12-2462-4f3c-a71f-3073d6ec28a2
# 22/04/03 00:04:56 INFO MemoryStore: MemoryStore started with capacity 366.3 MB
# 22/04/03 00:04:58 INFO SparkEnv: Registering OutputCommitCoordinator
# 22/04/03 00:05:07 WARN Utils: Service 'SparkUI' could not bind on port 4040. Attempting port 4041.
# 22/04/03 00:05:07 WARN Utils: Service 'SparkUI' could not bind on port 4041. Attempting port 4042.
# 22/04/03 00:05:07 WARN Utils: Service 'SparkUI' could not bind on port 4042. Attempting port 4043.
# 22/04/03 00:05:07 INFO Utils: Successfully started service 'SparkUI' on port 4043.
# 22/04/03 00:05:07 INFO SparkUI: Bound SparkUI to 0.0.0.0, and started at http://10.0.2.15:4043
# 22/04/03 00:05:14 INFO Executor: Starting executor ID driver on host localhost
# 22/04/03 00:05:20 INFO Utils: Successfully started service 'org.apache.spark.network.netty.NettyBlockTransferService' on port 43519.
# 22/04/03 00:05:20 INFO NettyBlockTransferService: Server created on 10.0.2.15:43519
# 22/04/03 00:05:20 INFO BlockManager: Using org.apache.spark.storage.RandomBlockReplicationPolicy for block replication policy
# 22/04/03 00:05:22 INFO BlockManagerMaster: Registering BlockManager BlockManagerId(driver, 10.0.2.15, 43519, None)
# 22/04/03 00:05:22 INFO BlockManagerMasterEndpoint: Registering block manager 10.0.2.15:43519 with 366.3 MB RAM, BlockManagerId(driver, 10.0.2.15, 43519, None)
# 22/04/03 00:05:23 INFO BlockManagerMaster: Registered BlockManager BlockManagerId(driver, 10.0.2.15, 43519, None)
# 22/04/03 00:05:23 INFO BlockManager: Initialized BlockManager: BlockManagerId(driver, 10.0.2.15, 43519, None)
# 22/04/03 00:06:02 INFO MemoryStore: Block broadcast_0 stored as values in memory (estimated size 237.4 KB, free 366.1 MB)
# 22/04/03 00:06:03 INFO MemoryStore: Block broadcast_0_piece0 stored as bytes in memory (estimated size 23.1 KB, free 366.0 MB)
# 22/04/03 00:06:03 INFO BlockManagerInfo: Added broadcast_0_piece0 in memory on 10.0.2.15:43519 (size: 23.1 KB, free: 366.3 MB)
# 22/04/03 00:06:03 INFO SparkContext: Created broadcast 0 from textFile at NativeMethodAccessorImpl.java:0
# 22/04/03 00:06:05 INFO FileInputFormat: Total input paths to process : 1
# 22/04/03 00:06:06 INFO SparkContext: Starting job: collect at /home/bitnami/Labs/Lab2/FliterLessFrequentWords.py:13
# 22/04/03 00:06:06 INFO DAGScheduler: Registering RDD 3 (reduceByKey at /home/bitnami/Labs/Lab2/FliterLessFrequentWords.py:11)
# 22/04/03 00:06:06 INFO DAGScheduler: Got job 0 (collect at /home/bitnami/Labs/Lab2/FliterLessFrequentWords.py:13) with 2 output partitions
# 22/04/03 00:06:06 INFO DAGScheduler: Final stage: ResultStage 1 (collect at /home/bitnami/Labs/Lab2/FliterLessFrequentWords.py:13)
# 22/04/03 00:06:06 INFO DAGScheduler: Parents of final stage: List(ShuffleMapStage 0)
# 22/04/03 00:06:06 INFO DAGScheduler: Missing parents: List(ShuffleMapStage 0)
# 22/04/03 00:06:06 INFO DAGScheduler: Submitting ShuffleMapStage 0 (PairwiseRDD[3] at reduceByKey at /home/bitnami/Labs/Lab2/FliterLessFrequentWords.py:11), which has no missing parents
# 22/04/03 00:06:07 INFO MemoryStore: Block broadcast_1 stored as values in memory (estimated size 11.2 KB, free 366.0 MB)
# 22/04/03 00:06:07 INFO MemoryStore: Block broadcast_1_piece0 stored as bytes in memory (estimated size 7.2 KB, free 366.0 MB)
# 22/04/03 00:06:07 INFO BlockManagerInfo: Added broadcast_1_piece0 in memory on 10.0.2.15:43519 (size: 7.2 KB, free: 366.3 MB)
# 22/04/03 00:06:07 INFO SparkContext: Created broadcast 1 from broadcast at DAGScheduler.scala:1161
# 22/04/03 00:06:07 INFO DAGScheduler: Submitting 2 missing tasks from ShuffleMapStage 0 (PairwiseRDD[3] at reduceByKey at /home/bitnami/Labs/Lab2/FliterLessFrequentWords.py:11) (first 15 tasks are for partitions Vector(0, 1))
# 22/04/03 00:06:07 INFO TaskSchedulerImpl: Adding task set 0.0 with 2 tasks
# 22/04/03 00:06:07 INFO TaskSetManager: Starting task 0.0 in stage 0.0 (TID 0, localhost, executor driver, partition 0, PROCESS_LOCAL, 7909 bytes)
# 22/04/03 00:06:07 INFO TaskSetManager: Starting task 1.0 in stage 0.0 (TID 1, localhost, executor driver, partition 1, PROCESS_LOCAL, 7909 bytes)
# 22/04/03 00:06:08 INFO Executor: Running task 1.0 in stage 0.0 (TID 1)
# 22/04/03 00:06:08 INFO Executor: Running task 0.0 in stage 0.0 (TID 0)
# 22/04/03 00:06:08 INFO HadoopRDD: Input split: file:/home/bitnami/Labs/Lab2/Data/AliceInWonderLandPart1.txt:0+609
# 22/04/03 00:06:08 INFO HadoopRDD: Input split: file:/home/bitnami/Labs/Lab2/Data/AliceInWonderLandPart1.txt:609+609
# 22/04/03 00:06:33 INFO PythonRunner: Times: total = 3196, boot = 997, init = 1930, finish = 269
# 22/04/03 00:06:33 INFO PythonRunner: Times: total = 3325, boot = 1013, init = 1932, finish = 380
# 22/04/03 00:06:33 INFO Executor: Finished task 1.0 in stage 0.0 (TID 1). 1716 bytes result sent to driver
# 22/04/03 00:06:33 INFO Executor: Finished task 0.0 in stage 0.0 (TID 0). 1716 bytes result sent to driver
# 22/04/03 00:06:33 INFO TaskSetManager: Finished task 0.0 in stage 0.0 (TID 0) in 26111 ms on localhost (executor driver) (1/2)
# 22/04/03 00:06:34 INFO TaskSetManager: Finished task 1.0 in stage 0.0 (TID 1) in 26071 ms on localhost (executor driver) (2/2)
# 22/04/03 00:06:34 INFO TaskSchedulerImpl: Removed TaskSet 0.0, whose tasks have all completed, from pool
# 22/04/03 00:06:34 INFO PythonAccumulatorV2: Connected to AccumulatorServer at host: 127.0.0.1 port: 46049
# 22/04/03 00:06:34 INFO DAGScheduler: ShuffleMapStage 0 (reduceByKey at /home/bitnami/Labs/Lab2/FliterLessFrequentWords.py:11) finished in 27.353 s
# 22/04/03 00:06:34 INFO DAGScheduler: looking for newly runnable stages
# 22/04/03 00:06:34 INFO DAGScheduler: running: Set()
# 22/04/03 00:06:34 INFO DAGScheduler: waiting: Set(ResultStage 1)
# 22/04/03 00:06:34 INFO DAGScheduler: failed: Set()
# 22/04/03 00:06:34 INFO DAGScheduler: Submitting ResultStage 1 (PythonRDD[6] at collect at /home/bitnami/Labs/Lab2/FliterLessFrequentWords.py:13), which has no missing parents
# 22/04/03 00:06:34 INFO MemoryStore: Block broadcast_2 stored as values in memory (estimated size 8.0 KB, free 366.0 MB)
# 22/04/03 00:06:34 INFO MemoryStore: Block broadcast_2_piece0 stored as bytes in memory (estimated size 5.2 KB, free 366.0 MB)
# 22/04/03 00:06:34 INFO BlockManagerInfo: Added broadcast_2_piece0 in memory on 10.0.2.15:43519 (size: 5.2 KB, free: 366.3 MB)
# 22/04/03 00:06:34 INFO SparkContext: Created broadcast 2 from broadcast at DAGScheduler.scala:1161
# 22/04/03 00:06:34 INFO DAGScheduler: Submitting 2 missing tasks from ResultStage 1 (PythonRDD[6] at collect at /home/bitnami/Labs/Lab2/FliterLessFrequentWords.py:13) (first 15 tasks are for partitions Vector(0, 1))
# 22/04/03 00:06:34 INFO TaskSchedulerImpl: Adding task set 1.0 with 2 tasks
# 22/04/03 00:06:35 INFO TaskSetManager: Starting task 0.0 in stage 1.0 (TID 2, localhost, executor driver, partition 0, ANY, 7662 bytes)
# 22/04/03 00:06:35 INFO TaskSetManager: Starting task 1.0 in stage 1.0 (TID 3, localhost, executor driver, partition 1, ANY, 7662 bytes)
# 22/04/03 00:06:35 INFO Executor: Running task 0.0 in stage 1.0 (TID 2)
# 22/04/03 00:06:36 INFO Executor: Running task 1.0 in stage 1.0 (TID 3)
# 22/04/03 00:06:38 INFO ShuffleBlockFetcherIterator: Getting 2 non-empty blocks including 2 local blocks and 0 remote blocks
# 22/04/03 00:06:38 INFO ShuffleBlockFetcherIterator: Getting 2 non-empty blocks including 2 local blocks and 0 remote blocks
# 22/04/03 00:06:38 INFO ShuffleBlockFetcherIterator: Started 0 remote fetches in 552 ms
# 22/04/03 00:06:38 INFO ShuffleBlockFetcherIterator: Started 0 remote fetches in 556 ms
# 22/04/03 00:06:40 INFO PythonRunner: Times: total = 409, boot = -27192, init = 27597, finish = 4
# 22/04/03 00:06:40 INFO PythonRunner: Times: total = 469, boot = -27066, init = 27518, finish = 17
# 22/04/03 00:06:40 INFO Executor: Finished task 1.0 in stage 1.0 (TID 3). 1867 bytes result sent to driver
# 22/04/03 00:06:40 INFO Executor: Finished task 0.0 in stage 1.0 (TID 2). 1806 bytes result sent to driver
# 22/04/03 00:06:40 INFO TaskSetManager: Finished task 1.0 in stage 1.0 (TID 3) in 4401 ms on localhost (executor driver) (1/2)
# 22/04/03 00:06:40 INFO TaskSetManager: Finished task 0.0 in stage 1.0 (TID 2) in 5766 ms on localhost (executor driver) (2/2)
# 22/04/03 00:06:40 INFO TaskSchedulerImpl: Removed TaskSet 1.0, whose tasks have all completed, from pool
# 22/04/03 00:06:40 INFO DAGScheduler: ResultStage 1 (collect at /home/bitnami/Labs/Lab2/FliterLessFrequentWords.py:13) finished in 5.958 s
# 22/04/03 00:06:40 INFO DAGScheduler: Job 0 finished: collect at /home/bitnami/Labs/Lab2/FliterLessFrequentWords.py:13, took 34.703256 s
# [('of', 8), ('her', 6), ('the', 12), ('it', 6), ('and', 6), ('a', 8), ('to', 7)]
# 22/04/03 00:06:41 INFO SparkContext: Invoking stop() from shutdown hook
# 22/04/03 00:06:41 INFO SparkUI: Stopped Spark web UI at http://10.0.2.15:4043
# 22/04/03 00:06:42 INFO MapOutputTrackerMasterEndpoint: MapOutputTrackerMasterEndpoint stopped!
# 22/04/03 00:06:42 INFO MemoryStore: MemoryStore cleared
# 22/04/03 00:06:42 INFO BlockManager: BlockManager stopped
# 22/04/03 00:06:42 INFO BlockManagerMaster: BlockManagerMaster stopped
# 22/04/03 00:06:42 INFO OutputCommitCoordinator$OutputCommitCoordinatorEndpoint: OutputCommitCoordinator stopped!
# 22/04/03 00:06:42 INFO SparkContext: Successfully stopped SparkContext
# 22/04/03 00:06:42 INFO ShutdownHookManager: Shutdown hook called
# 22/04/03 00:06:42 INFO ShutdownHookManager: Deleting directory /tmp/spark-987c60d3-9e06-44c9-9da8-eec3b2b5fd26
# 22/04/03 00:06:42 INFO ShutdownHookManager: Deleting directory /tmp/spark-987c60d3-9e06-44c9-9da8-eec3b2b5fd26/pyspark-88bfd5bb-c34e-469b-9544-fac0808f1583
# 22/04/03 00:06:42 INFO ShutdownHookManager: Deleting directory /tmp/spark-85db8230-9122-4457-b572-a5503223a7ca

# %%
## Task 3: Modify task #1 so as to return the longest *line* :

# %%
# !spark-submit LongestLine.py
# Out:
# 22/04/03 00:33:03 WARN Utils: Your hostname, debian resolves to a loopback address: 127.0.0.1; using 10.0.2.15 instead (on interface enp0s3)
# 22/04/03 00:33:03 WARN Utils: Set SPARK_LOCAL_IP if you need to bind to another address
# 22/04/03 00:33:08 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# Using Spark's default log4j profile: org/apache/spark/log4j-defaults.properties
# 22/04/03 00:33:18 INFO SparkContext: Running Spark version 2.4.3
# 22/04/03 00:33:21 INFO SparkContext: Submitted application: LongestLine
# 22/04/03 00:33:27 INFO SecurityManager: Changing view acls to: nu
# 22/04/03 00:33:27 INFO SecurityManager: Changing modify acls to: nu
# 22/04/03 00:33:27 INFO SecurityManager: Changing view acls groups to:
# 22/04/03 00:33:27 INFO SecurityManager: Changing modify acls groups to:
# 22/04/03 00:33:28 INFO SecurityManager: SecurityManager: authentication disabled; ui acls disabled; users  with view permissions: Set(nu); groups with view permissions: Set(); users  with modify permissions: Set(nu); groups with modify permissions: Set()
# 22/04/03 00:33:51 INFO Utils: Successfully started service 'sparkDriver' on port 44649.
# 22/04/03 00:33:52 INFO SparkEnv: Registering MapOutputTracker
# 22/04/03 00:33:53 INFO SparkEnv: Registering BlockManagerMaster
# 22/04/03 00:33:53 INFO BlockManagerMasterEndpoint: Using org.apache.spark.storage.DefaultTopologyMapper for getting topology information
# 22/04/03 00:33:53 INFO BlockManagerMasterEndpoint: BlockManagerMasterEndpoint up
# 22/04/03 00:33:54 INFO DiskBlockManager: Created local directory at /tmp/blockmgr-22e079aa-c16f-4850-b7f3-48ed27f07f49
# 22/04/03 00:33:56 INFO MemoryStore: MemoryStore started with capacity 366.3 MB
# 22/04/03 00:33:59 INFO SparkEnv: Registering OutputCommitCoordinator
# 22/04/03 00:34:06 WARN Utils: Service 'SparkUI' could not bind on port 4040. Attempting port 4041.
# 22/04/03 00:34:06 WARN Utils: Service 'SparkUI' could not bind on port 4041. Attempting port 4042.
# 22/04/03 00:34:06 WARN Utils: Service 'SparkUI' could not bind on port 4042. Attempting port 4043.
# 22/04/03 00:34:06 INFO Utils: Successfully started service 'SparkUI' on port 4043.
# 22/04/03 00:34:07 INFO SparkUI: Bound SparkUI to 0.0.0.0, and started at http://10.0.2.15:4043
# 22/04/03 00:34:08 INFO Executor: Starting executor ID driver on host localhost
# 22/04/03 00:34:09 INFO Utils: Successfully started service 'org.apache.spark.network.netty.NettyBlockTransferService' on port 35955.
# 22/04/03 00:34:09 INFO NettyBlockTransferService: Server created on 10.0.2.15:35955
# 22/04/03 00:34:09 INFO BlockManager: Using org.apache.spark.storage.RandomBlockReplicationPolicy for block replication policy
# 22/04/03 00:34:09 INFO BlockManagerMaster: Registering BlockManager BlockManagerId(driver, 10.0.2.15, 35955, None)
# 22/04/03 00:34:09 INFO BlockManagerMasterEndpoint: Registering block manager 10.0.2.15:35955 with 366.3 MB RAM, BlockManagerId(driver, 10.0.2.15, 35955, None)
# 22/04/03 00:34:09 INFO BlockManagerMaster: Registered BlockManager BlockManagerId(driver, 10.0.2.15, 35955, None)
# 22/04/03 00:34:09 INFO BlockManager: Initialized BlockManager: BlockManagerId(driver, 10.0.2.15, 35955, None)
# 22/04/03 00:34:53 INFO MemoryStore: Block broadcast_0 stored as values in memory (estimated size 237.4 KB, free 366.1 MB)
# 22/04/03 00:34:55 INFO MemoryStore: Block broadcast_0_piece0 stored as bytes in memory (estimated size 23.1 KB, free 366.0 MB)
# 22/04/03 00:34:55 INFO BlockManagerInfo: Added broadcast_0_piece0 in memory on 10.0.2.15:35955 (size: 23.1 KB, free: 366.3 MB)
# 22/04/03 00:34:55 INFO SparkContext: Created broadcast 0 from textFile at NativeMethodAccessorImpl.java:0
# 22/04/03 00:35:01 INFO FileInputFormat: Total input paths to process : 1
# 22/04/03 00:35:04 INFO SparkContext: Starting job: reduce at /home/bitnami/Labs/Lab2/LongestLine.py:15
# 22/04/03 00:35:04 INFO DAGScheduler: Got job 0 (reduce at /home/bitnami/Labs/Lab2/LongestLine.py:15) with 2 output partitions
# 22/04/03 00:35:04 INFO DAGScheduler: Final stage: ResultStage 0 (reduce at /home/bitnami/Labs/Lab2/LongestLine.py:15)
# 22/04/03 00:35:04 INFO DAGScheduler: Parents of final stage: List()
# 22/04/03 00:35:04 INFO DAGScheduler: Missing parents: List()
# 22/04/03 00:35:04 INFO DAGScheduler: Submitting ResultStage 0 (PythonRDD[2] at reduce at /home/bitnami/Labs/Lab2/LongestLine.py:15), which has no missing parents
# 22/04/03 00:35:04 INFO MemoryStore: Block broadcast_1 stored as values in memory (estimated size 7.5 KB, free 366.0 MB)
# 22/04/03 00:35:05 INFO MemoryStore: Block broadcast_1_piece0 stored as bytes in memory (estimated size 4.8 KB, free 366.0 MB)
# 22/04/03 00:35:05 INFO BlockManagerInfo: Added broadcast_1_piece0 in memory on 10.0.2.15:35955 (size: 4.8 KB, free: 366.3 MB)
# 22/04/03 00:35:05 INFO SparkContext: Created broadcast 1 from broadcast at DAGScheduler.scala:1161
# 22/04/03 00:35:05 INFO DAGScheduler: Submitting 2 missing tasks from ResultStage 0 (PythonRDD[2] at reduce at /home/bitnami/Labs/Lab2/LongestLine.py:15) (first 15 tasks are for partitions Vector(0, 1))
# 22/04/03 00:35:05 INFO TaskSchedulerImpl: Adding task set 0.0 with 2 tasks
# 22/04/03 00:35:06 INFO TaskSetManager: Starting task 0.0 in stage 0.0 (TID 0, localhost, executor driver, partition 0, PROCESS_LOCAL, 7920 bytes)
# 22/04/03 00:35:06 INFO TaskSetManager: Starting task 1.0 in stage 0.0 (TID 1, localhost, executor driver, partition 1, PROCESS_LOCAL, 7920 bytes)
# 22/04/03 00:35:06 INFO Executor: Running task 0.0 in stage 0.0 (TID 0)
# 22/04/03 00:35:06 INFO Executor: Running task 1.0 in stage 0.0 (TID 1)
# 22/04/03 00:35:07 INFO HadoopRDD: Input split: file:/home/bitnami/Labs/Lab2/Data/AliceInWonderLandPart1.txt:609+609
# 22/04/03 00:35:07 INFO HadoopRDD: Input split: file:/home/bitnami/Labs/Lab2/Data/AliceInWonderLandPart1.txt:0+609
# 22/04/03 00:35:12 INFO PythonRunner: Times: total = 5422, boot = 4475, init = 898, finish = 49
# 22/04/03 00:35:12 INFO PythonRunner: Times: total = 5435, boot = 4371, init = 1030, finish = 34
# 22/04/03 00:35:13 INFO Executor: Finished task 1.0 in stage 0.0 (TID 1). 1504 bytes result sent to driver
# 22/04/03 00:35:13 INFO Executor: Finished task 0.0 in stage 0.0 (TID 0). 1547 bytes result sent to driver
# 22/04/03 00:35:13 INFO TaskSetManager: Finished task 1.0 in stage 0.0 (TID 1) in 7470 ms on localhost (executor driver) (1/2)
# 22/04/03 00:35:13 INFO TaskSetManager: Finished task 0.0 in stage 0.0 (TID 0) in 7707 ms on localhost (executor driver) (2/2)
# 22/04/03 00:35:14 INFO TaskSchedulerImpl: Removed TaskSet 0.0, whose tasks have all completed, from pool
# 22/04/03 00:35:14 INFO PythonAccumulatorV2: Connected to AccumulatorServer at host: 127.0.0.1 port: 46149
# 22/04/03 00:35:14 INFO DAGScheduler: ResultStage 0 (reduce at /home/bitnami/Labs/Lab2/LongestLine.py:15) finished in 9.254 s
# 22/04/03 00:35:14 INFO DAGScheduler: Job 0 finished: reduce at /home/bitnami/Labs/Lab2/LongestLine.py:15, took 10.384940 s
# 22/04/03 00:35:15 INFO SparkContext: Invoking stop() from shutdown hook
# 22/04/03 00:35:15 INFO SparkUI: Stopped Spark web UI at http://10.0.2.15:4043
# 22/04/03 00:35:16 INFO MapOutputTrackerMasterEndpoint: MapOutputTrackerMasterEndpoint stopped!
# 22/04/03 00:35:16 INFO MemoryStore: MemoryStore cleared
# 22/04/03 00:35:16 INFO BlockManager: BlockManager stopped
# 22/04/03 00:35:16 INFO BlockManagerMaster: BlockManagerMaster stopped
# 22/04/03 00:35:17 INFO OutputCommitCoordinator$OutputCommitCoordinatorEndpoint: OutputCommitCoordinator stopped!
# 22/04/03 00:35:17 INFO SparkContext: Successfully stopped SparkContext
# 22/04/03 00:35:17 INFO ShutdownHookManager: Shutdown hook called
# 22/04/03 00:35:17 INFO ShutdownHookManager: Deleting directory /tmp/spark-a0997f10-503b-4714-a766-061aee13a9a5/pyspark-abff762d-040a-42ac-9f6f-d2b7785bfdac
# 22/04/03 00:35:17 INFO ShutdownHookManager: Deleting directory /tmp/spark-a0997f10-503b-4714-a766-061aee13a9a5
# 22/04/03 00:35:17 INFO ShutdownHookManager: Deleting directory /tmp/spark-2b9d7746-bd5f-4cf5-9587-ea83e6caa64f

# %%
## Task 4: Average Movie Rate

# %%
# !spark-submit AverageMovieRate.py
# Out:
# 22/04/03 00:29:40 WARN Utils: Your hostname, debian resolves to a loopback address: 127.0.0.1; using 10.0.2.15 instead (on interface enp0s3)
# 22/04/03 00:29:40 WARN Utils: Set SPARK_LOCAL_IP if you need to bind to another address
# 22/04/03 00:30:05 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# Using Spark's default log4j profile: org/apache/spark/log4j-defaults.properties
# 22/04/03 00:30:13 INFO SparkContext: Running Spark version 2.4.3
# 22/04/03 00:30:14 INFO SparkContext: Submitted application: SparkFilterWordCount
# 22/04/03 00:30:18 INFO SecurityManager: Changing view acls to: nu
# 22/04/03 00:30:18 INFO SecurityManager: Changing modify acls to: nu
# 22/04/03 00:30:18 INFO SecurityManager: Changing view acls groups to:
# 22/04/03 00:30:18 INFO SecurityManager: Changing modify acls groups to:
# 22/04/03 00:30:18 INFO SecurityManager: SecurityManager: authentication disabled; ui acls disabled; users  with view permissions: Set(nu); groups with view permissions: Set(); users  with modify permissions: Set(nu); groups with modify permissions: Set()
# 22/04/03 00:30:39 INFO Utils: Successfully started service 'sparkDriver' on port 33599.
# 22/04/03 00:30:41 INFO SparkEnv: Registering MapOutputTracker
# 22/04/03 00:30:42 INFO SparkEnv: Registering BlockManagerMaster
# 22/04/03 00:30:43 INFO BlockManagerMasterEndpoint: Using org.apache.spark.storage.DefaultTopologyMapper for getting topology information
# 22/04/03 00:30:43 INFO BlockManagerMasterEndpoint: BlockManagerMasterEndpoint up
# 22/04/03 00:30:46 INFO DiskBlockManager: Created local directory at /tmp/blockmgr-65f61e2e-332b-4acc-82b7-4d81289a8978
# 22/04/03 00:30:47 INFO MemoryStore: MemoryStore started with capacity 366.3 MB
# 22/04/03 00:30:48 INFO SparkEnv: Registering OutputCommitCoordinator
# 22/04/03 00:30:51 WARN Utils: Service 'SparkUI' could not bind on port 4040. Attempting port 4041.
# 22/04/03 00:30:51 WARN Utils: Service 'SparkUI' could not bind on port 4041. Attempting port 4042.
# 22/04/03 00:30:51 WARN Utils: Service 'SparkUI' could not bind on port 4042. Attempting port 4043.
# 22/04/03 00:30:53 INFO Utils: Successfully started service 'SparkUI' on port 4043.
# 22/04/03 00:30:55 INFO SparkUI: Bound SparkUI to 0.0.0.0, and started at http://10.0.2.15:4043
# 22/04/03 00:31:00 INFO Executor: Starting executor ID driver on host localhost
# 22/04/03 00:31:03 INFO Utils: Successfully started service 'org.apache.spark.network.netty.NettyBlockTransferService' on port 39155.
# 22/04/03 00:31:03 INFO NettyBlockTransferService: Server created on 10.0.2.15:39155
# 22/04/03 00:31:03 INFO BlockManager: Using org.apache.spark.storage.RandomBlockReplicationPolicy for block replication policy
# 22/04/03 00:31:04 INFO BlockManagerMaster: Registering BlockManager BlockManagerId(driver, 10.0.2.15, 39155, None)
# 22/04/03 00:31:04 INFO BlockManagerMasterEndpoint: Registering block manager 10.0.2.15:39155 with 366.3 MB RAM, BlockManagerId(driver, 10.0.2.15, 39155, None)
# 22/04/03 00:31:04 INFO BlockManagerMaster: Registered BlockManager BlockManagerId(driver, 10.0.2.15, 39155, None)
# 22/04/03 00:31:04 INFO BlockManager: Initialized BlockManager: BlockManagerId(driver, 10.0.2.15, 39155, None)
# 22/04/03 00:31:44 INFO MemoryStore: Block broadcast_0 stored as values in memory (estimated size 237.4 KB, free 366.1 MB)
# 22/04/03 00:31:49 INFO MemoryStore: Block broadcast_0_piece0 stored as bytes in memory (estimated size 23.1 KB, free 366.0 MB)
# 22/04/03 00:31:49 INFO BlockManagerInfo: Added broadcast_0_piece0 in memory on 10.0.2.15:39155 (size: 23.1 KB, free: 366.3 MB)
# 22/04/03 00:31:51 INFO SparkContext: Created broadcast 0 from textFile at NativeMethodAccessorImpl.java:0
# 22/04/03 00:31:58 INFO FileInputFormat: Total input paths to process : 1
# 22/04/03 00:32:01 INFO SparkContext: Starting job: collect at /home/bitnami/Labs/Lab2/AverageMovieRate.py:17
# 22/04/03 00:32:02 INFO DAGScheduler: Registering RDD 3 (aggregateByKey at /home/bitnami/Labs/Lab2/AverageMovieRate.py:14)
# 22/04/03 00:32:02 INFO DAGScheduler: Got job 0 (collect at /home/bitnami/Labs/Lab2/AverageMovieRate.py:17) with 2 output partitions
# 22/04/03 00:32:02 INFO DAGScheduler: Final stage: ResultStage 1 (collect at /home/bitnami/Labs/Lab2/AverageMovieRate.py:17)
# 22/04/03 00:32:02 INFO DAGScheduler: Parents of final stage: List(ShuffleMapStage 0)
# 22/04/03 00:32:02 INFO DAGScheduler: Missing parents: List(ShuffleMapStage 0)
# 22/04/03 00:32:02 INFO DAGScheduler: Submitting ShuffleMapStage 0 (PairwiseRDD[3] at aggregateByKey at /home/bitnami/Labs/Lab2/AverageMovieRate.py:14), which has no missing parents
# 22/04/03 00:32:03 INFO MemoryStore: Block broadcast_1 stored as values in memory (estimated size 11.9 KB, free 366.0 MB)
# 22/04/03 00:32:03 INFO MemoryStore: Block broadcast_1_piece0 stored as bytes in memory (estimated size 7.7 KB, free 366.0 MB)
# 22/04/03 00:32:03 INFO BlockManagerInfo: Added broadcast_1_piece0 in memory on 10.0.2.15:39155 (size: 7.7 KB, free: 366.3 MB)
# 22/04/03 00:32:03 INFO SparkContext: Created broadcast 1 from broadcast at DAGScheduler.scala:1161
# 22/04/03 00:32:03 INFO DAGScheduler: Submitting 2 missing tasks from ShuffleMapStage 0 (PairwiseRDD[3] at aggregateByKey at /home/bitnami/Labs/Lab2/AverageMovieRate.py:14) (first 15 tasks are for partitions Vector(0, 1))
# 22/04/03 00:32:03 INFO TaskSchedulerImpl: Adding task set 0.0 with 2 tasks
# 22/04/03 00:32:04 INFO TaskSetManager: Starting task 0.0 in stage 0.0 (TID 0, localhost, executor driver, partition 0, PROCESS_LOCAL, 7884 bytes)
# 22/04/03 00:32:04 INFO TaskSetManager: Starting task 1.0 in stage 0.0 (TID 1, localhost, executor driver, partition 1, PROCESS_LOCAL, 7884 bytes)
# 22/04/03 00:32:04 INFO Executor: Running task 1.0 in stage 0.0 (TID 1)
# 22/04/03 00:32:04 INFO Executor: Running task 0.0 in stage 0.0 (TID 0)
# 22/04/03 00:32:05 INFO HadoopRDD: Input split: file:/home/bitnami/Labs/Lab2/u.data:989586+989587
# 22/04/03 00:32:05 INFO HadoopRDD: Input split: file:/home/bitnami/Labs/Lab2/u.data:0+989586
# 22/04/03 00:32:17 INFO PythonRunner: Times: total = 2286, boot = 961, init = 257, finish = 1068
# 22/04/03 00:32:17 INFO PythonRunner: Times: total = 2406, boot = 977, init = 189, finish = 1240
# 22/04/03 00:32:17 INFO Executor: Finished task 0.0 in stage 0.0 (TID 0). 1759 bytes result sent to driver
# 22/04/03 00:32:17 INFO Executor: Finished task 1.0 in stage 0.0 (TID 1). 1759 bytes result sent to driver
# 22/04/03 00:32:17 INFO TaskSetManager: Finished task 1.0 in stage 0.0 (TID 1) in 13625 ms on localhost (executor driver) (1/2)
# 22/04/03 00:32:17 INFO TaskSetManager: Finished task 0.0 in stage 0.0 (TID 0) in 14096 ms on localhost (executor driver) (2/2)
# 22/04/03 00:32:17 INFO TaskSchedulerImpl: Removed TaskSet 0.0, whose tasks have all completed, from pool
# 22/04/03 00:32:18 INFO PythonAccumulatorV2: Connected to AccumulatorServer at host: 127.0.0.1 port: 40637
# 22/04/03 00:32:18 INFO DAGScheduler: ShuffleMapStage 0 (aggregateByKey at /home/bitnami/Labs/Lab2/AverageMovieRate.py:14) finished in 15.324 s
# 22/04/03 00:32:18 INFO DAGScheduler: looking for newly runnable stages
# 22/04/03 00:32:18 INFO DAGScheduler: running: Set()
# 22/04/03 00:32:18 INFO DAGScheduler: waiting: Set(ResultStage 1)
# 22/04/03 00:32:18 INFO DAGScheduler: failed: Set()
# 22/04/03 00:32:18 INFO DAGScheduler: Submitting ResultStage 1 (PythonRDD[6] at collect at /home/bitnami/Labs/Lab2/AverageMovieRate.py:17), which has no missing parents
# 22/04/03 00:32:18 INFO MemoryStore: Block broadcast_2 stored as values in memory (estimated size 8.7 KB, free 366.0 MB)
# 22/04/03 00:32:18 INFO MemoryStore: Block broadcast_2_piece0 stored as bytes in memory (estimated size 5.6 KB, free 366.0 MB)
# 22/04/03 00:32:18 INFO BlockManagerInfo: Added broadcast_2_piece0 in memory on 10.0.2.15:39155 (size: 5.6 KB, free: 366.3 MB)
# 22/04/03 00:32:18 INFO SparkContext: Created broadcast 2 from broadcast at DAGScheduler.scala:1161
# 22/04/03 00:32:18 INFO DAGScheduler: Submitting 2 missing tasks from ResultStage 1 (PythonRDD[6] at collect at /home/bitnami/Labs/Lab2/AverageMovieRate.py:17) (first 15 tasks are for partitions Vector(0, 1))
# 22/04/03 00:32:18 INFO TaskSchedulerImpl: Adding task set 1.0 with 2 tasks
# 22/04/03 00:32:18 INFO TaskSetManager: Starting task 0.0 in stage 1.0 (TID 2, localhost, executor driver, partition 0, ANY, 7662 bytes)
# 22/04/03 00:32:18 INFO TaskSetManager: Starting task 1.0 in stage 1.0 (TID 3, localhost, executor driver, partition 1, ANY, 7662 bytes)
# 22/04/03 00:32:18 INFO Executor: Running task 0.0 in stage 1.0 (TID 2)
# 22/04/03 00:32:18 INFO Executor: Running task 1.0 in stage 1.0 (TID 3)
# 22/04/03 00:32:18 INFO ShuffleBlockFetcherIterator: Getting 2 non-empty blocks including 2 local blocks and 0 remote blocks
# 22/04/03 00:32:18 INFO ShuffleBlockFetcherIterator: Getting 2 non-empty blocks including 2 local blocks and 0 remote blocks
# 22/04/03 00:32:18 INFO ShuffleBlockFetcherIterator: Started 0 remote fetches in 65 ms
# 22/04/03 00:32:18 INFO ShuffleBlockFetcherIterator: Started 0 remote fetches in 70 ms
# 22/04/03 00:32:20 INFO PythonRunner: Times: total = 964, boot = -11174, init = 12106, finish = 32
# 22/04/03 00:32:20 INFO PythonRunner: Times: total = 1076, boot = -11137, init = 12172, finish = 41
# 22/04/03 00:32:20 INFO Executor: Finished task 1.0 in stage 1.0 (TID 3). 8889 bytes result sent to driver
# 22/04/03 00:32:20 INFO Executor: Finished task 0.0 in stage 1.0 (TID 2). 8832 bytes result sent to driver
# 22/04/03 00:32:20 INFO TaskSetManager: Finished task 1.0 in stage 1.0 (TID 3) in 2253 ms on localhost (executor driver) (1/2)
# 22/04/03 00:32:20 INFO TaskSetManager: Finished task 0.0 in stage 1.0 (TID 2) in 2437 ms on localhost (executor driver) (2/2)
# 22/04/03 00:32:20 INFO TaskSchedulerImpl: Removed TaskSet 1.0, whose tasks have all completed, from pool
# 22/04/03 00:32:20 INFO DAGScheduler: ResultStage 1 (collect at /home/bitnami/Labs/Lab2/AverageMovieRate.py:17) finished in 2.523 s
# 22/04/03 00:32:23 INFO DAGScheduler: Job 0 finished: collect at /home/bitnami/Labs/Lab2/AverageMovieRate.py:17, took 21.586226 s
# [(2, 3.7096774193548385), (4, 4.333333333333333), (6, 3.6350710900473935), (8, 3.7966101694915255), (10, 4.206521739130435), (12, 4.392156862745098), (14, 4.091836734693878), (16, 4.328571428571428), (18, 3.88086642599278), (20, 3.1041666666666665), (22, 3.3515625), (24, 4.323529411764706), (26, 2.94392523364486), (28, 3.721518987341772), (30, 3.7674418604651163), (32, 3.317073170731707), (34, 4.05), (36, 3.8), (38, 3.71900826446281), (40, 2.8857142857142857), (42, 3.726775956284153), (44, 3.6490066225165565), (46, 4.111111111111111), (48, 3.787878787878788), (50, 3.5416666666666665), (52, 4.267857142857143), (54, 3.6923076923076925), (56, 3.641711229946524), (58, 3.8376623376623376), (60, 4.086538461538462), (62, 3.3017241379310347), (64, 3.585), (66, 3.473684210526316), (68, 3.0294117647058822), (70, 3.4656488549618323), (72, 3.8175182481751824), (74, 3.641025641025641), (76, 3.5609756097560976), (78, 3.380952380952381), (80, 3.7586206896551726), (82, 3.0714285714285716), (84, 3.8529411764705883), (86, 3.5217391304347827), (88, 3.9523809523809526), (90, 4.223333333333334), (92, 3.2448453608247423), (94, 3.6575), (96, 4.267857142857143), (98, 3.5925925925925926), (100, 3.0677966101694913), (102, 2.615740740740741), (104, 2.6666666666666665), (106, 3.765625), (108, 3.5757575757575757), (110, 3.045112781954887), (112, 3.6956521739130435), (114, 3.6041666666666665), (116, 3.006993006993007), (118, 4.661971830985915), (120, 3.576923076923077), (122, 3.9836065573770494), (124, 3.5), (126, 3.533333333333333), (128, 3.6630434782608696), (130, 3.9858356940509916), (132, 3.772727272727273), (134, 3.64), (136, 4.3428571428571425), (138, 4.2745098039215685), (140, 3.4285714285714284), (142, 3.6363636363636362), (144, 3.674757281553398), (146, 3.6206896551724137), (148, 4.0), (150, 3.84375), (152, 4.320754716981132), (154, 3.9607843137254903), (156, 3.72972972972973), (158, 3.8034682080924855), (160, 3.9166666666666665), (162, 3.5952380952380953), (164, 4.126984126984127), (166, 3.55), (168, 3.3333333333333335), (170, 3.772727272727273), (172, 3.185185185185185), (174, 3.5819209039548023), (176, 3.6984126984126986), (178, 3.681318681318681), (180, 3.9365079365079363), (182, 3.857142857142857), (184, 3.6613545816733066), (186, 3.4130434782608696), (188, 3.767857142857143), (190, 3.3220338983050848), (192, 3.5142857142857142), (194, 2.963934426229508), (196, 3.6153846153846154), (198, 3.276243093922652), (200, 4.032407407407407), (202, 2.8), (204, 3.4523809523809526), (206, 2.171875), (208, 3.787878787878788), (210, 4.0606060606060606), (212, 3.92), (214, 3.8984375), (216, 3.801526717557252), (218, 3.6037735849056602), (220, 3.772727272727273), (222, 3.049095607235142), (224, 2.99290780141844), (226, 3.8), (228, 3.142857142857143), (230, 3.8496240601503757), (232, 3.903225806451613), (234, 3.122916666666667), (236, 3.475806451612903), (238, 3.2758620689655173), (240, 3.75), (242, 4.45), (244, 3.6512605042016806), (246, 2.928205128205128), (248, 3.5714285714285716), (250, 3.7868852459016393), (252, 4.428571428571429), (254, 3.050314465408805), (256, 3.9903381642512077), (258, 3.739130434782609), (260, 4.041666666666667), (262, 3.16875), (264, 4.216666666666667), (266, 3.260869565217391), (268, 2.942073170731707), (270, 4.333333333333333), (272, 4.333333333333333), (274, 4.056338028169014), (276, 3.465250965250965), (278, 4.260869565217392), (280, 3.5775193798449614), (282, 3.5), (284, 3.5531914893617023), (286, 3.7118055555555554), (288, 3.88), (290, 3.3533333333333335), (292, 4.225806451612903), (294, 3.466666666666667), (296, 4.1768707482993195), (298, 4.031496062992126), (300, 3.75), (302, 2.4285714285714284), (304, 3.3846153846153846), (306, 3.78125), (308, 3.7581863979848866), (310, 3.857142857142857), (312, 4.381165919282512), (314, 3.6775510204081634), (316, 3.36), (318, 3.706896551724138), (320, 3.720779220779221), (322, 4.176470588235294), (324, 4.348484848484849), (326, 3.3262032085561497), (328, 3.431095406360424), (330, 4.496598 ...
# 22/04/03 00:32:25 INFO SparkContext: Invoking stop() from shutdown hook
# 22/04/03 00:32:25 INFO SparkUI: Stopped Spark web UI at http://10.0.2.15:4043
# 22/04/03 00:32:26 INFO MapOutputTrackerMasterEndpoint: MapOutputTrackerMasterEndpoint stopped!
# 22/04/03 00:32:26 INFO MemoryStore: MemoryStore cleared
# 22/04/03 00:32:26 INFO BlockManager: BlockManager stopped
# 22/04/03 00:32:26 INFO BlockManagerMaster: BlockManagerMaster stopped
# 22/04/03 00:32:26 INFO OutputCommitCoordinator$OutputCommitCoordinatorEndpoint: OutputCommitCoordinator stopped!
# 22/04/03 00:32:26 INFO SparkContext: Successfully stopped SparkContext
# 22/04/03 00:32:26 INFO ShutdownHookManager: Shutdown hook called
# 22/04/03 00:32:26 INFO ShutdownHookManager: Deleting directory /tmp/spark-224912b9-9213-49d8-bfd5-a5b4a667556b/pyspark-d6ed230e-0f43-44c6-8e42-30428b732c71
# 22/04/03 00:32:26 INFO ShutdownHookManager: Deleting directory /tmp/spark-224912b9-9213-49d8-bfd5-a5b4a667556b
# 22/04/03 00:32:26 INFO ShutdownHookManager: Deleting directory /tmp/spark-51ca8f99-8da7-48b5-af87-98a29d8e098e
